# %% [markdown]
# # Pandas 2.0 using Pyarrow backend

# %%
# !pip install pandas==2.2.3
# !pip install pyarrow==19.0.0
# Out:
# Requirement already satisfied: pandas==2.2.3 in /opt/conda/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.3) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.3) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.3) (2025.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.17.0)
# Requirement already satisfied: pyarrow==19.0.0 in /opt/conda/lib/python3.12/site-packages (19.0.0)

# %%
import pandas as pd
import time
import statistics

# %%
# %run utilities.ipynb
# Out:
# Requirement already satisfied: pandas==2.2.3 in /opt/conda/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.3) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.3) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.12/site-packages (from pandas==2.2.3) (2025.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas==2.2.3) (1.17.0)

# %%
config_engine = "Pyarrow" # Pyarrow or C

if config_engine == "Pyarrow":
    kwargs_read_csv = {"engine":"pyarrow"}
    filename = "Pandas2.0Pyarrow"
else:
    kwargs_read_csv = {}
    filename = "Pandas2.0Numpy"

filename += ".csv"

# %% [markdown]
# ## Reading file

# %%
total_read = []
for i in range(REPETITIONS): 
    start_time = time.time()
    df = pd.read_csv("Imdb Movie Dataset.csv", **kwargs_read_csv)
    time_reading_file = time.time() - start_time
    total_read.append(time_reading_file)
print("--- %s seconds ---" % sum(total_read))
# Out:
# --- 138.25511598587036 seconds ---

# %%
df
# Out:
#              id                        title  vote_average  vote_count  \
# 0         27205                    Inception         8.364       34495
# 1        157336                 Interstellar         8.417       32571
# 2           155              The Dark Knight         8.512       30619
# 3         19995                       Avatar         7.573       29815
# 4         24428                 The Avengers         7.710       29166
# ...         ...                          ...           ...         ...
# 1048570  905156             鐨勯鏍肩殑椋庢牸儇妒呢蛹刹偎头         0.000           0
# 1048571  905157             MILF & Cookies 3         0.000           0
# 1048572  905158        The Choice of Staying         0.000           0
# 1048573  905161  Luisa Schluckt Schon Wieder         0.000           0
# 1048574  905163   Little White Slave Girls 8         0.000           0
#
#            status release_date     revenue  runtime  adult     budget  ...  \
# 0        Released    7/15/2010   825532764      148  False  160000000  ...
# 1        Released    11/5/2014   701729206      169  False  165000000  ...
# 2        Released    7/16/2008  1004558444      152  False  185000000  ...
# 3        Released   12/15/2009  2923706026      162  False  237000000  ...
# 4        Released    4/25/2012  1518815515      143  False  220000000  ...
# ...           ...          ...         ...      ...    ...        ...  ...
# 1048570  Released         None           0        0  False          0  ...
# 1048571  Released         None           0        0   True          0  ...
# 1048572  Released    10/8/2020           0        0  False          0  ...
# 1048573  Released    5/13/2016           0        0   True          0  ...
# 1048574  Released         None           0        0   True          0  ...
#
#         original_language               original_title  \
# 0                      en                    Inception
# 1                      en                 Interstellar
# 2                      en              The Dark Knight
# 3                      en                       Avatar
# 4                      en                 The Avengers
# ...                   ...                          ...
# 1048570                zh             鐨勯鏍肩殑椋庢牸儇妒呢蛹刹偎头
# 1048571                en             MILF & Cookies 3
# 1048572                it        The Choice of Staying
# 1048573                de  Luisa Schluckt Schon Wieder
# 1048574                en   Little White Slave Girls 8
#
#                                                   overview popularity  \
# 0        Cobb, a skilled thief who commits corporate es...     83.952
# 1        The adventures of a group of explorers who mak...    140.241
# 2        Batman raises the stakes in his war on crime. ...    130.643
# 3        In the 22nd century, a paraplegic Marine is di...     79.932
# 4        When an unexpected enemy emerges and threatens...     98.082
# ...                                                    ...        ...
# 1048570                                               None      0.600
# 1048571                                               None      0.600
# 1048572                                               None      0.600
# 1048573                                               None      0.600
# 1048574                                               None      0.600
#
#                                                    tagline  \
# 0                     Your mind is the scene of the crime.
# 1        Mankind was born on Earth. It was never meant ...
# 2                        Welcome to a world without rules.
# 3                              Enter the world of Pandora.
# 4                                  Some assembly required.
# ...                                                    ...
# 1048570                                               None
# 1048571                                               None
# 1048572                                               None
# 1048573                                               None
# 1048574                                               None
#
#                                               genres  \
# 0                 Action, Science Fiction, Adventure
# 1                  Adventure, Drama, Science Fiction
# 2                     Drama, Action, Crime, Thriller
# 3        Action, Adventure, Fantasy, Science Fiction
# 4                 Science Fiction, Action, Adventure
# ...                                              ...
# 1048570                                         None
# 1048571                                         None
# 1048572                                  Documentary
# 1048573                                         None
# 1048574                                         None
#
#                                       production_companies  \
# 0        Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1        Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2        DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3        Dune Entertainment, Lightstorm Entertainment, ...
# 4                                           Marvel Studios
# ...                                                    ...
# 1048570                                               None
# 1048571                                               None
# 1048572                                               None
# 1048573                          John Thompson Productions
# 1048574                                               None
#
#                              production_countries  \
# 0        United Kingdom, United States of America
# 1        United Kingdom, United States of America
# 2        United Kingdom, United States of America
# 3        United States of America, United Kingdom
# 4                        United States of America
# ...                                           ...
# 1048570                                      None
# 1048571                                      None
# 1048572                                      None
# 1048573                                      None
# 1048574                                      None
#
#                            spoken_languages  \
# 0        English, French, Japanese, Swahili
# 1                                   English
# 2                         English, Mandarin
# 3                          English, Spanish
# 4                   English, Hindi, Russian
# ...                                     ...
# 1048570                                None
# 1048571                                None
# 1048572           English, Italian, Swedish
# 1048573                                None
# 1048574                                None
#
#                                                   keywords
# 0        rescue, mission, dream, airplane, paris, franc...
# 1        rescue, future, spacecraft, race against time,...
# 2        joker, sadism, chaos, secret identity, crime f...
# 3        future, society, culture clash, space travel, ...
# 4        new york city, superhero, shield, based on com...
# ...                                                    ...
# 1048570                                               None
# 1048571                                               None
# 1048572                                               None
# 1048573                                               None
# 1048574                                               None
#
# [1048575 rows x 21 columns]

# %%
df.memory_usage(index=True, deep = True).sum()
# Out:
# np.int64(1010114540)

# %% [markdown]
# ## Cleaning data
#
# Things that we are going to remove and measure only once
# - No release Date and status is released
# - Runtime 0 or Null
# - Budget 0. It has to cost something
# - It has to have a genre

# %%
data_cleaned = df[~((df["status"] == "Released") & (df["release_date"].isnull()))]
data_cleaned = data_cleaned[(data_cleaned["runtime"] > 0) & (data_cleaned["runtime"].notnull())]
data_cleaned = data_cleaned[(data_cleaned["budget"] > 0)]
data_cleaned = data_cleaned[(df["genres"].notnull())]
# Out:
# /tmp/ipykernel_35958/1295375744.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   data_cleaned = data_cleaned[(df["genres"].notnull())]

# %%
data_cleaned
# Out:
#              id                                   title  vote_average  \
# 0         27205                               Inception         8.364
# 1        157336                            Interstellar         8.417
# 2           155                         The Dark Knight         8.512
# 3         19995                                  Avatar         7.573
# 4         24428                            The Avengers         7.710
# ...         ...                                     ...           ...
# 1048326  904802                    Last Ride of The Day         0.000
# 1048549  905056           Saint Nicolas chez les Baltus         0.000
# 1048550  905057                    Les Baltus Au Cirque         0.000
# 1048555  905063    Science Please! : The Force of Water         0.000
# 1048557  905065  Science Please! : Wheel Meets Friction         0.000
#
#          vote_count    status release_date     revenue  runtime  adult  \
# 0             34495  Released    7/15/2010   825532764      148  False
# 1             32571  Released    11/5/2014   701729206      169  False
# 2             30619  Released    7/16/2008  1004558444      152  False
# 3             29815  Released   12/15/2009  2923706026      162  False
# 4             29166  Released    4/25/2012  1518815515      143  False
# ...             ...       ...          ...         ...      ...    ...
# 1048326           0  Released   11/14/2020           0       17  False
# 1048549           0  Released    12/1/1993       32896        4  False
# 1048550           0  Released    8/20/1999       27378        6  False
# 1048555           0  Released     1/1/1998       43134        1  False
# 1048557           0  Released     1/1/1998        5477        1  False
#
#             budget  ... original_language  \
# 0        160000000  ...                en
# 1        165000000  ...                en
# 2        185000000  ...                en
# 3        237000000  ...                en
# 4        220000000  ...                en
# ...            ...  ...               ...
# 1048326       3000  ...                id
# 1048549      32896  ...                en
# 1048550      27378  ...                en
# 1048555      43134  ...                en
# 1048557       5477  ...                en
#
#                                  original_title  \
# 0                                     Inception
# 1                                  Interstellar
# 2                               The Dark Knight
# 3                                        Avatar
# 4                                  The Avengers
# ...                                         ...
# 1048326                               Boncengan
# 1048549           Saint Nicolas chez les Baltus
# 1048550                    Les Baltus Au Cirque
# 1048555    Science Please! : The Force of Water
# 1048557  Science Please! : Wheel Meets Friction
#
#                                                   overview popularity  \
# 0        Cobb, a skilled thief who commits corporate es...     83.952
# 1        The adventures of a group of explorers who mak...    140.241
# 2        Batman raises the stakes in his war on crime. ...    130.643
# 3        In the 22nd century, a paraplegic Marine is di...     79.932
# 4        When an unexpected enemy emerges and threatens...     98.082
# ...                                                    ...        ...
# 1048326  Nadia (15) spends her last day riding a motorb...      0.600
# 1048549  the Animated Short Film by Stéphane Aubier and...      0.600
# 1048550  the Animated Short Film by Stéphane Aubier and...      0.600
# 1048555  A clip in the Science Please! collection, The ...      0.600
# 1048557  A clip in the Science Please! collection, Whee...      0.600
#
#                                                    tagline  \
# 0                     Your mind is the scene of the crime.
# 1        Mankind was born on Earth. It was never meant ...
# 2                        Welcome to a world without rules.
# 3                              Enter the world of Pandora.
# 4                                  Some assembly required.
# ...                                                    ...
# 1048326                                               None
# 1048549                                               None
# 1048550                                               None
# 1048555                                               None
# 1048557                                               None
#
#                                               genres  \
# 0                 Action, Science Fiction, Adventure
# 1                  Adventure, Drama, Science Fiction
# 2                     Drama, Action, Crime, Thriller
# 3        Action, Adventure, Fantasy, Science Fiction
# 4                 Science Fiction, Action, Adventure
# ...                                              ...
# 1048326                                Drama, Family
# 1048549                                    Animation
# 1048550                                    Animation
# 1048555                                    Animation
# 1048557                                    Animation
#
#                                       production_companies  \
# 0        Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1        Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2        DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3        Dune Entertainment, Lightstorm Entertainment, ...
# 4                                           Marvel Studios
# ...                                                    ...
# 1048326  Halaman Belakang Film, Sineman Films, UMN (Uni...
# 1048549                                               None
# 1048550                                               None
# 1048555                                          ONF | NFB
# 1048557                                          ONF | NFB
#
#                              production_countries  \
# 0        United Kingdom, United States of America
# 1        United Kingdom, United States of America
# 2        United Kingdom, United States of America
# 3        United States of America, United Kingdom
# 4                        United States of America
# ...                                           ...
# 1048326                                 Indonesia
# 1048549                                    France
# 1048550                                    France
# 1048555                                    Canada
# 1048557                                    Canada
#
#                            spoken_languages  \
# 0        English, French, Japanese, Swahili
# 1                                   English
# 2                         English, Mandarin
# 3                          English, Spanish
# 4                   English, Hindi, Russian
# ...                                     ...
# 1048326                          Indonesian
# 1048549                              French
# 1048550                              French
# 1048555                             English
# 1048557                             English
#
#                                                   keywords
# 0        rescue, mission, dream, airplane, paris, franc...
# 1        rescue, future, spacecraft, race against time,...
# 2        joker, sadism, chaos, secret identity, crime f...
# 3        future, society, culture clash, space travel, ...
# 4        new york city, superhero, shield, based on com...
# ...                                                    ...
# 1048326                                               None
# 1048549                                               None
# 1048550                                               None
# 1048555                                              water
# 1048557                                          big wheel
#
# [38100 rows x 21 columns]

# %% [markdown]
# ## Select

# %%
total_select = []
for i in range(REPETITIONS): 
    start_time = time.time()
    data_cleaned = data_cleaned[[c for c in data_cleaned.columns if c not in [
    "overview", "tagline","genres", "production_companies","production_countries","spoken_languages", "keywords"]
                                   ]]
    time_select = time.time() - start_time
    total_select.append(time_select)
print("--- %s seconds ---" % sum(total_select))
# Out:
# --- 0.1979837417602539 seconds ---

# %% [markdown]
# ## Filter

# %%
total_filter = []
for i in range(REPETITIONS):
    start_time = time.time()
    df_filter = data_cleaned[data_cleaned["budget"] > 550000000]
    time_filter = time.time() - start_time
    total_filter.append(time_filter)
print("--- %s seconds ---" % sum(total_filter))
# Out:
# --- 0.015083074569702148 seconds ---

# %%
df_filter
# Out:
#              id                    title  vote_average  vote_count    status  \
# 507929  1057999                     Enea           0.0           0  Released
# 707555  1224207  Adventures in Bora Bora           0.0           0  Released
#
#        release_date     revenue  runtime  adult     budget     imdb_id  \
# 507929    9/21/2023           0      115  False  888000000  tt27219440
# 707555    8/23/2023  3000000000        5  False  800000000        None
#
#        original_language           original_title  popularity
# 507929                it                     Enea       4.319
# 707555                en  Adventures in Bora Bora       0.000

# %% [markdown]
# ## Aggregation

# %%
total_agg = []
for i in range(REPETITIONS):
    start_time = time.time()
    df_agg = data_cleaned[["status","runtime"]].groupby(["status"]).mean()
    time_agg = time.time() - start_time
    total_agg.append(time_agg)
print("--- %s seconds ---" % sum(total_agg))
# Out:
# --- 0.17758917808532715 seconds ---

# %%
df_agg
# Out:
#                    runtime
# status
# Canceled         27.285714
# In Production    38.623446
# Planned          41.858407
# Post Production  41.353968
# Released         71.266654
# Rumored          63.000000

# %% [markdown]
# ## Sorting

# %%
total_sort = []
for i in range(REPETITIONS):
    start_time = time.time()
    df_sort = data_cleaned.sort_values(["revenue"])
    time_sort = time.time() - start_time
    total_sort.append(time_sort)
print("--- %s seconds ---" % sum(total_sort))
# Out:
# --- 0.34035730361938477 seconds ---

# %%
df_sort
# Out:
#              id                     title  vote_average  vote_count  \
# 207944    64767                  Deadrise         1.500           2
# 184774   763484          Die by the Sword         5.500           2
# 518782  1400372             Without Mercy         0.000           0
# 184738  1036417        Sunflower's Friend         7.500           2
# 184636   323867                       Spy         5.500           2
# ...         ...                       ...           ...         ...
# 282       76600  Avatar: The Way of Water         7.654        9830
# 15       299534         Avengers: Endgame         8.263       23857
# 3         19995                    Avatar         7.573       29815
# 707555  1224207   Adventures in Bora Bora         0.000           0
# 234307  1270893         TikTok Rizz Party        10.000           1
#
#                  status release_date     revenue  runtime  adult     budget  \
# 207944         Released     4/5/2011           0       95  False    1000000
# 184774         Released    10/6/2020           0       90  False     500000
# 518782  Post Production         None           0       20  False      50000
# 184738         Released    9/25/2022           0        2  False       1000
# 184636         Released     8/9/2011           0      110  False    5000000
# ...                 ...          ...         ...      ...    ...        ...
# 282            Released   12/14/2022  2320250281      192  False  460000000
# 15             Released    4/24/2019  2800000000      181  False  356000000
# 3              Released   12/15/2009  2923706026      162  False  237000000
# 707555         Released    8/23/2023  3000000000        5  False  800000000
# 234307         Released     4/1/2024  3000000000      180  False  250000000
#
#            imdb_id original_language            original_title  popularity
# 207944   tt1552192                en                  Deadrise       0.840
# 184774  tt12484058                en          Die by the Sword       1.216
# 518782  tt30477702                en             Without Mercy       0.600
# 184738  tt21236962                en        Sunflower's Friend       0.701
# 184636   tt0372538                en                       Spy       1.497
# ...            ...               ...                       ...         ...
# 282      tt1630029                en  Avatar: The Way of Water     241.285
# 15       tt4154796                en         Avengers: Endgame      91.756
# 3        tt0499549                en                    Avatar      79.932
# 707555        None                en   Adventures in Bora Bora       0.000
# 234307        None                en         TikTok Rizz Party       0.000
#
# [38100 rows x 14 columns]

# %% [markdown]
# ## Complex Execution

# %%
total_complex = []
for i in range(REPETITIONS):
    start_time = time.time()
    data_cleaned["release_date"] = pd.to_datetime(data_cleaned["release_date"], format="mixed")
    revenue_2024 = data_cleaned[(data_cleaned["release_date"] >= '2024-01-01') & (data_cleaned["release_date"] <= '2024-12-31')] 
    revenue_2024_non_en = revenue_2024[revenue_2024["original_language"] != "en"]
    max_revenue_2024_by_language = revenue_2024[["original_language","revenue"]].groupby(["original_language"]).max()
    max_revenue_2024_by_language_non = revenue_2024_non_en[["original_language","revenue"]].groupby(["original_language"]).max()
    time_complex = time.time() - start_time
    total_complex.append(time_complex)
print("--- %s seconds ---" % sum(total_complex))
max_revenue_2024_by_language_non
# Out:
# --- 0.6554312705993652 seconds ---
#                    revenue
# original_language
# ar                      10
# as                       0
# az                       0
# bg                       0
# bn                       0
# ca                       0
# cs                       0
# da                       0
# de                       0
# el                       0
# es                     500
# et                       0
# fa                       0
# fi                       0
# fr                     300
# gu                       0
# he                       0
# hi                     100
# hr                       0
# hu                       0
# id                       0
# is                       0
# it                       0
# ja                       0
# km                       0
# ko                       0
# ku                       0
# lt                       0
# ml                    2500
# mn                       0
# mr                       0
# my                       0
# ne                       0
# nl                       0
# no                       0
# om                       0
# pa                       0
# pl                       0
# pt                       1
# qu                       0
# ro                       0
# ru                       0
# sk                       0
# sr                      50
# sv                       0
# ta                       0
# te                       0
# th                       0
# tl                       0
# tn                       0
# tr                     445
# uk                       0
# ur                       0
# xx                       0
# zh                       0

# %% [markdown]
# ## Saving metrics

# %%
data_list = ["sum","avg","min","max"]
write_list = []
for x in data_list:
    data = {}
    fun = sum if x == "sum" else statistics.mean if x == "avg" else min if x == "min" else max
    data["type"] = x
    data["read_file"] = fun(total_read)
    data["memory_size_read"] = df.memory_usage(index=True, deep = True).sum()
    data["select"] = fun(total_select)
    data["memory_size_select"] = data_cleaned.memory_usage(index=True, deep = True).sum()
    data["filter"] = fun(total_filter)
    data["memory_size_filter"] = df_filter.memory_usage(index=True, deep = True).sum()
    data["agg"] = fun(total_agg)
    data["memory_size_agg"] = df_agg.memory_usage(index=True, deep = True).sum()
    data["sort"] = fun(total_sort)
    data["memory_size_sort"] = df_sort.memory_usage(index=True, deep = True).sum()
    data["complex"] = fun(total_complex)
    data["memory_size_complex"] = max_revenue_2024_by_language_non.memory_usage(index=True, deep = True).sum()
    data["repetitions"] = REPETITIONS
    write_list.append(data)
write_csv(filename,write_list)
